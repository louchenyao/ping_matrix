# %%
import pandas as pd

# %%
p = pd.read_csv("ping.csv").drop(columns=['Unnamed: 0'])
p.date = pd.to_datetime(p.date).dt.time
p = p.pivot(index='date', columns='target', values='rtt')
ax = p.plot()
ax.set_ylabel('ping (ms)')
ax.plot()
# Out:
# []
